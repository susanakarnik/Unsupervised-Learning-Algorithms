# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('F:\MarketData.csv', header = None)

# %%
transactions = []
for i in range(0, 7501):
    transactions.append([str(dataset.values[i,j]) for j in range(0, 20)])

# %%
from apyori import apriori

# %%
rules = apriori(transactions, 
                min_support = 0.003,
                min_confidence = 0.2,
                min_lift = 3,
                min_length = 2)

# %%
MB = list(rules)
Result = [list(MB[i][0]) for i in range(0,len(MB))]

# %%
Result
# Out:
# [['light cream', 'chicken'],
#  ['escalope', 'mushroom cream sauce'],
#  ['escalope', 'pasta'],
#  ['honey', 'fromage blanc'],
#  ['herb & pepper', 'ground beef'],
#  ['ground beef', 'tomato sauce'],
#  ['light cream', 'olive oil'],
#  ['whole wheat pasta', 'olive oil'],
#  ['shrimp', 'pasta'],
#  ['avocado', 'spaghetti', 'milk'],
#  ['milk', 'burgers', 'cake'],
#  ['chocolate', 'turkey', 'burgers'],
#  ['turkey', 'burgers', 'milk'],
#  ['frozen vegetables', 'cake', 'tomatoes'],
#  ['cereals', 'ground beef', 'spaghetti'],
#  ['chicken', 'ground beef', 'milk'],
#  ['light cream', 'chicken', 'nan'],
#  ['chicken', 'olive oil', 'milk'],
#  ['chicken', 'spaghetti', 'olive oil'],
#  ['chocolate', 'frozen vegetables', 'shrimp'],
#  ['chocolate', 'herb & pepper', 'ground beef'],
#  ['chocolate', 'soup', 'milk'],
#  ['cooking oil', 'ground beef', 'spaghetti'],
#  ['herb & pepper', 'eggs', 'ground beef'],
#  ['eggs', 'red wine', 'spaghetti'],
#  ['escalope', 'mushroom cream sauce', 'nan'],
#  ['escalope', 'pasta', 'nan'],
#  ['french fries', 'herb & pepper', 'ground beef'],
#  ['honey', 'nan', 'fromage blanc'],
#  ['frozen vegetables', 'tomatoes', 'green tea'],
#  ['frozen vegetables', 'ground beef', 'spaghetti'],
#  ['frozen vegetables', 'olive oil', 'milk'],
#  ['frozen vegetables', 'soup', 'milk'],
#  ['frozen vegetables', 'tomatoes', 'milk'],
#  ['frozen vegetables', 'mineral water', 'shrimp'],
#  ['frozen vegetables', 'spaghetti', 'olive oil'],
#  ['frozen vegetables', 'spaghetti', 'shrimp'],
#  ['frozen vegetables', 'tomatoes', 'shrimp'],
#  ['frozen vegetables', 'spaghetti', 'tomatoes'],
#  ['grated cheese', 'ground beef', 'spaghetti'],
#  ['tomatoes', 'ground beef', 'green tea'],
#  ['herb & pepper', 'ground beef', 'milk'],
#  ['herb & pepper', 'mineral water', 'ground beef'],
#  ['herb & pepper', 'ground beef', 'nan'],
#  ['herb & pepper', 'ground beef', 'spaghetti'],
#  ['ground beef', 'olive oil', 'milk'],
#  ['soup', 'ground beef', 'milk'],
#  ['ground beef', 'tomato sauce', 'nan'],
#  ['ground beef', 'spaghetti', 'pepper'],
#  ['shrimp', 'ground beef', 'spaghetti'],
#  ['ground beef', 'spaghetti', 'tomato sauce'],
#  ['light cream', 'mineral water', 'spaghetti'],
#  ['olive oil', 'light cream', 'nan'],
#  ['shrimp', 'olive oil', 'milk'],
#  ['soup', 'olive oil', 'milk'],
#  ['spaghetti', 'olive oil', 'milk'],
#  ['soup', 'tomatoes', 'milk'],
#  ['whole wheat pasta', 'spaghetti', 'milk'],
#  ['soup', 'mineral water', 'olive oil'],
#  ['mineral water', 'whole wheat pasta', 'olive oil'],
#  ['olive oil', 'whole wheat pasta', 'nan'],
#  ['pasta', 'nan', 'shrimp'],
#  ['pancakes', 'spaghetti', 'olive oil'],
#  ['spaghetti', 'olive oil', 'tomatoes'],
#  ['whole wheat rice', 'spaghetti', 'tomatoes'],
#  ['avocado', 'spaghetti', 'nan', 'milk'],
#  ['milk', 'burgers', 'nan', 'cake'],
#  ['chocolate', 'turkey', 'burgers', 'nan'],
#  ['turkey', 'burgers', 'nan', 'milk'],
#  ['frozen vegetables', 'cake', 'nan', 'tomatoes'],
#  ['cereals', 'ground beef', 'spaghetti', 'nan'],
#  ['chicken', 'ground beef', 'nan', 'milk'],
#  ['olive oil', 'chicken', 'nan', 'milk'],
#  ['olive oil', 'chicken', 'spaghetti', 'nan'],
#  ['chocolate', 'mineral water', 'eggs', 'ground beef'],
#  ['chocolate', 'frozen vegetables', 'mineral water', 'ground beef'],
#  ['chocolate', 'frozen vegetables', 'ground beef', 'spaghetti'],
#  ['chocolate', 'frozen vegetables', 'mineral water', 'milk'],
#  ['chocolate', 'frozen vegetables', 'spaghetti', 'milk'],
#  ['chocolate', 'frozen vegetables', 'mineral water', 'shrimp'],
#  ['chocolate', 'frozen vegetables', 'nan', 'shrimp'],
#  ['chocolate', 'herb & pepper', 'ground beef', 'nan'],
#  ['chocolate', 'soup', 'nan', 'milk'],
#  ['chocolate', 'mineral water', 'spaghetti', 'olive oil'],
#  ['chocolate', 'mineral water', 'spaghetti', 'shrimp'],
#  ['cooking oil', 'ground beef', 'spaghetti', 'nan'],
#  ['frozen vegetables', 'mineral water', 'eggs', 'milk'],
#  ['herb & pepper', 'eggs', 'ground beef', 'nan'],
#  ['eggs', 'red wine', 'spaghetti', 'nan'],
#  ['french fries', 'herb & pepper', 'ground beef', 'nan'],
#  ['frozen smoothie', 'mineral water', 'spaghetti', 'milk'],
#  ['frozen vegetables', 'tomatoes', 'nan', 'green tea'],
#  ['frozen vegetables', 'mineral water', 'ground beef', 'milk'],
#  ['frozen vegetables', 'ground beef', 'spaghetti', 'milk'],
#  ['frozen vegetables', 'mineral water', 'ground beef', 'spaghetti'],
#  ['frozen vegetables', 'ground beef', 'spaghetti', 'nan'],
#  ['frozen vegetables', 'mineral water', 'olive oil', 'milk'],
#  ['frozen vegetables', 'mineral water', 'soup', 'milk'],
#  ['frozen vegetables', 'mineral water', 'spaghetti', 'milk'],
#  ['frozen vegetables', 'olive oil', 'nan', 'milk'],
#  ['frozen vegetables', 'soup', 'nan', 'milk'],
#  ['frozen vegetables', 'tomatoes', 'nan', 'milk'],
#  ['frozen vegetables', 'mineral water', 'nan', 'shrimp'],
#  ['frozen vegetables', 'mineral water', 'spaghetti', 'shrimp'],
#  ['frozen vegetables', 'mineral water', 'spaghetti', 'tomatoes'],
#  ['frozen vegetables', 'spaghetti', 'olive oil', 'nan'],
#  ['frozen vegetables', 'spaghetti', 'nan', 'shrimp'],
#  ['frozen vegetables', 'tomatoes', 'nan', 'shrimp'],
#  ['frozen vegetables', 'spaghetti', 'nan', 'tomatoes'],
#  ['grated cheese', 'ground beef', 'spaghetti', 'nan'],
#  ['tomatoes', 'ground beef', 'nan', 'green tea'],
#  ['herb & pepper', 'ground beef', 'nan', 'milk'],
#  ['herb & pepper', 'mineral water', 'ground beef', 'nan'],
#  ['herb & pepper', 'ground beef', 'spaghetti', 'nan'],
#  ['mineral water', 'ground beef', 'spaghetti', 'milk'],
#  ['olive oil', 'ground beef', 'nan', 'milk'],
#  ['soup', 'ground beef', 'nan', 'milk'],
#  ['mineral water', 'ground beef', 'spaghetti', 'olive oil'],
#  ['pancakes', 'mineral water', 'ground beef', 'spaghetti'],
#  ['mineral water', 'ground beef', 'spaghetti', 'tomatoes'],
#  ['ground beef', 'spaghetti', 'nan', 'pepper'],
#  ['shrimp', 'ground beef', 'spaghetti', 'nan'],
#  ['tomato sauce', 'ground beef', 'spaghetti', 'nan'],
#  ['light cream', 'mineral water', 'spaghetti', 'nan'],
#  ['mineral water', 'spaghetti', 'olive oil', 'milk'],
#  ['mineral water', 'tomatoes', 'spaghetti', 'milk'],
#  ['olive oil', 'shrimp', 'nan', 'milk'],
#  ['olive oil', 'soup', 'nan', 'milk'],
#  ['olive oil', 'spaghetti', 'nan', 'milk'],
#  ['soup', 'tomatoes', 'nan', 'milk'],
#  ['whole wheat pasta', 'spaghetti', 'nan', 'milk'],
#  ['olive oil', 'mineral water', 'soup', 'nan'],
#  ['olive oil', 'mineral water', 'whole wheat pasta', 'nan'],
#  ['olive oil', 'pancakes', 'spaghetti', 'nan'],
#  ['olive oil', 'spaghetti', 'nan', 'tomatoes'],
#  ['whole wheat rice', 'spaghetti', 'nan', 'tomatoes'],
#  ['mineral water', 'chocolate', 'ground beef', 'nan', 'eggs'],
#  ['mineral water', 'frozen vegetables', 'chocolate', 'ground beef', 'nan'],
#  ['frozen vegetables', 'chocolate', 'ground beef', 'spaghetti', 'nan'],
#  ['mineral water', 'frozen vegetables', 'milk', 'chocolate', 'nan'],
#  ['frozen vegetables', 'milk', 'chocolate', 'spaghetti', 'nan'],
#  ['mineral water', 'frozen vegetables', 'chocolate', 'nan', 'shrimp'],
#  ['mineral water', 'olive oil', 'chocolate', 'spaghetti', 'nan'],
#  ['mineral water', 'chocolate', 'spaghetti', 'nan', 'shrimp'],
#  ['mineral water', 'frozen vegetables', 'milk', 'nan', 'eggs'],
#  ['mineral water', 'milk', 'spaghetti', 'nan', 'frozen smoothie'],
#  ['mineral water', 'frozen vegetables', 'milk', 'ground beef', 'nan'],
#  ['frozen vegetables', 'milk', 'ground beef', 'spaghetti', 'nan'],
#  ['mineral water', 'frozen vegetables', 'ground beef', 'spaghetti', 'nan'],
#  ['mineral water', 'olive oil', 'frozen vegetables', 'milk', 'nan'],
#  ['mineral water', 'frozen vegetables', 'soup', 'milk', 'nan'],
#  ['mineral water', 'frozen vegetables', 'milk', 'spaghetti', 'nan'],
#  ['mineral water', 'frozen vegetables', 'spaghetti', 'nan', 'shrimp'],
#  ['mineral water', 'frozen vegetables', 'tomatoes', 'spaghetti', 'nan'],
#  ['mineral water', 'milk', 'ground beef', 'spaghetti', 'nan'],
#  ['mineral water', 'olive oil', 'ground beef', 'spaghetti', 'nan'],
#  ['mineral water', 'pancakes', 'ground beef', 'spaghetti', 'nan'],
#  ['mineral water', 'tomatoes', 'ground beef', 'spaghetti', 'nan'],
#  ['mineral water', 'olive oil', 'milk', 'spaghetti', 'nan'],
#  ['mineral water', 'tomatoes', 'milk', 'spaghetti', 'nan']]
